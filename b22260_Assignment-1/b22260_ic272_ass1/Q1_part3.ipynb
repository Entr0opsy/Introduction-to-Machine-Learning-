# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("C:/Users/sksin/OneDrive/Desktop/IC272/Assignment-1/landslide_data_original.csv")
df
# Out:
#           dates stationid  temperature  humidity     pressure      rain  \
# 0    08-07-2018       t10     25.46875  82.18750  1036.346875      6.75
# 1    09-07-2018       t10     26.19298  83.14912  1037.604386   1761.75
# 2    10-07-2018       t10     25.17021  85.34043  1037.889362    652.50
# 3    11-07-2018       t10     24.29851  87.68657  1036.857463    963.00
# 4    12-07-2018       t10     24.06923  87.64615  1027.830769    254.25
# ..          ...       ...          ...       ...          ...       ...
# 940  21-11-2018        t9     16.65926  58.69630  1026.797407  73577.25
# 941  22-11-2018        t9     15.52482  63.16312  1027.495248  65301.75
# 942  23-11-2018        t9     15.81560  59.21277  1029.318511  73534.50
# 943  24-11-2018        t9     16.58571  54.63571  1026.776357  72283.50
# 944  25-11-2018        t9     17.90000  49.41000  1026.771200  71799.75
#
#       lightavg  lightmax  moisture
# 0       5.5000      4000    0.0000
# ...

# %%
x=df.groupby("stationid").get_group("t12")
x
# Out:
#           dates stationid  temperature  humidity     pressure     rain  \
# 194  05-07-2018       t12     21.00000  93.50000   882.735000     0.00
# 195  09-07-2018       t12     25.55238  31.00000  1000.000000     1.00
# 196  13-07-2018       t12     25.55238  31.00000  1005.780000     0.00
# 197  16-07-2018       t12     25.55238  86.96190  1005.498095    47.25
# 198  17-07-2018       t12     24.55639  92.56391  1008.306015  1710.00
# ..          ...       ...          ...       ...          ...      ...
# 316  21-11-2018       t12     14.63492  59.45238  1055.343651     0.00
# 317  22-11-2018       t12     13.14286  68.75188  1056.087970     0.00
# 318  23-11-2018       t12     13.54478  62.60448  1057.887313     0.00
# 319  24-11-2018       t12     14.58015  54.17557  1055.096183     0.00
# 320  25-11-2018       t12     16.18557  51.61856  1055.103093     0.00
#
#       lightavg  lightmax  moisture
# 194   302.0000      4000    2.0000
# 195     1.0000      4000    1.0000
# ...

# %%
hum_t12=x["humidity"].tolist()
print(hum_t12)
#given bin size =5 implies that no of bins will be len(hum_t12)/5 ka int 

bins=int(len(hum_t12)/5)
# Out:
# [93.5, 31.0, 31.0, 86.9619, 92.56391, 88.37209, 84.14815, 90.66197, 94.18116, 96.68056, 94.4065, 97.66901, 94.84211, 99.0, 98.95775, 99.0, 92.52817, 88.25954, 91.26056, 91.17986, 91.37778, 90.69504, 99.0, 98.70769, 98.23611, 99.0, 93.75352, 93.42958, 95.47183, 95.50355, 98.95745, 93.41667, 95.84615, 98.89286, 96.91489, 99.0, 98.41844, 95.67133, 96.46479, 93.72857, 94.02797, 96.12676, 98.0, 98.6993, 96.49306, 99.0, 99.0, 98.26471, 98.97183, 97.67832, 95.49286, 96.33099, 97.01408, 96.6993, 97.69231, 93.68613, 97.5, 94.36842, 95.66197, 88.35211, 86.67133, 86.65035, 82.44681, 78.67606, 85.91608, 99.0, 99.0, 99.0, 88.71127, 85.90071, 85.6338, 91.5625, 86.06338, 86.74306, 84.0, 74.44366, 72.51748, 64.17857, 67.93056, 64.42657, 68.13287, 74.8662, 55.63889, 50.77465, 83.57746, 81.73427, 81.32639, 80.82517, 74.1958, 63.29787, 58.71528, 57.45139, 49.40972, 53.94444, 52.02113, 53.74126, 49.10417, 53.67857, 52.27083, 55.43662, 61.57143, 84.37209, 80.1194, 83.6194, 97.44444, 82.41481, 76.79851, 7
# ...

# %%
plt.hist(hum_t12, bins=bins, edgecolor="yellow")
plt.xlabel("Data values")
plt.ylabel("Frequency for the corresponding data value ")
plt.title("Histogram plot for Humidity")
plt.show()
